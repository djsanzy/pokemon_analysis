# %%
import pandas as pd

import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ZOMMY\\Jupyter Projects1\\Pandas D_1'

# %%
os.listdir('C://Users/ZOMMY/Desktop/Mail Merge Project Start')
# Out:
# ['.DS_Store',
#  '.idea',
#  'example.txt',
#  'file1.txt',
#  'file2.txt',
#  'Input',
#  'invited_names.txt',
#  'main.py',
#  'names.csv',
#  'nato_phonetic_alphabet.csv',
#  'Output',
#  'pokemon_data.csv',
#  'squirrel_count.csv',
#  'squirrel_data_2018.csv',
#  'starting_letter.txt',
#  'venv',
#  'weather_sheet.csv']

# %%
df = pd.read_csv('C://Users/ZOMMY/Desktop/Mail Merge Project Start/pokemon_data.csv', index_col='#')

pd.set_option('display.max_columns', 11)

pd.set_option('display.max_rows', 11)

# %%
df
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49       65
# 2                  Ivysaur    Grass  Poison  60      62       63       80
# 3                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 719                Diancie     Rock   Fairy  50     100      150      100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 721              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
df.shape
# Out:
# (800, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 1 to 721
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   HP          800 non-null    int64
#  4   Attack      800 non-null    int64
#  5   Defense     800 non-null    int64
#  6   Sp. Atk     800 non-null    int64
#  7   Sp. Def     800 non-null    int64
#  8   Speed       800 non-null    int64
#  9   Generation  800 non-null    int64
#  10  Legendary   800 non-null    bool
# dtypes: bool(1), int64(7), object(3)
# memory usage: 69.5+ KB

# %%
df.head(10)
# Out:
#                         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# #
# 1                  Bulbasaur  Grass  Poison  45      49       49       65
# 2                    Ivysaur  Grass  Poison  60      62       63       80
# 3                   Venusaur  Grass  Poison  80      82       83      100
# 3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4                 Charmander   Fire     NaN  39      52       43       60
# 5                 Charmeleon   Fire     NaN  58      64       58       80
# 6                  Charizard   Fire  Flying  78      84       78      109
# 6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# ...

# %%
df.tail(10)
# Out:
#                     Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# #
# 714               Noibat   Flying  Dragon   40      30       35       45
# 715              Noivern   Flying  Dragon   85      70       80       97
# 716              Xerneas    Fairy     NaN  126     131       95      131
# 717              Yveltal     Dark  Flying  126     131       95      131
# 718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 719              Diancie     Rock   Fairy   50     100      150      100
# 719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# #
# 714       40     55           6      False
# 715       80    123           6      False
# ...

# %%
# I had to rename some columns, i replaced the spaces with underscores, it's easier for me that way

df.rename(columns= {'Type 1': 'Type_1', 'Type 2': 'Type_2', 'Sp. Atk': 'Sp_Atk', 'Sp. Def': 'Sp_Def'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Name', 'Type_1', 'Type_2', 'HP', 'Attack', 'Defense', 'Sp_Atk',
#        'Sp_Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
filt = df['Speed'] > 70

# %%
df.loc[filt, ['Name', 'Type 1', 'Type 2', 'Generation', 'Speed']]
# Out:
#                           Name   Type 1  Type 2  Generation  Speed
# #
# 3                     Venusaur    Grass  Poison           1     80
# 3        VenusaurMega Venusaur    Grass  Poison           1     80
# 5                   Charmeleon     Fire     NaN           1     80
# 6                    Charizard     Fire  Flying           1    100
# 6    CharizardMega Charizard X     Fire  Dragon           1    100
# ..                         ...      ...     ...         ...    ...
# 716                    Xerneas    Fairy     NaN           6     99
# 717                    Yveltal     Dark  Flying           6     99
# 718           Zygarde50% Forme   Dragon  Ground           6     95
# 719        DiancieMega Diancie     Rock   Fairy           6    110
# 720         HoopaHoopa Unbound  Psychic    Dark           6     80
#
# [337 rows x 5 columns]

# %%
df.loc[filt, ['Name', 'Type_1', 'Type_2', 'Generation', 'Speed']]
# Out:
#            Name  Type_1 Type_2  Generation  Speed
# #
# 4    Charmander    Fire    NaN           1     65
# 5    Charmeleon    Fire    NaN           1     80
# 7      Squirtle   Water    NaN           1     43
# 8     Wartortle   Water    NaN           1     58
# 9     Blastoise   Water    NaN           1     78
# ..          ...     ...    ...         ...    ...
# 705     Sliggoo  Dragon    NaN           6     60
# 706      Goodra  Dragon    NaN           6     80
# 712    Bergmite     Ice    NaN           6     28
# 713     Avalugg     Ice    NaN           6     28
# 716     Xerneas   Fairy    NaN           6     99
#
# [386 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df
# Out:
#                       Name   Type_1  Type_2  HP  Attack  Defense  Sp_Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49      65
# 2                  Ivysaur    Grass  Poison  60      62       63      80
# 3                 Venusaur    Grass  Poison  80      82       83     100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123     122
# 4               Charmander     Fire     NaN  39      52       43      60
# ..                     ...      ...     ...  ..     ...      ...     ...
# 719                Diancie     Rock   Fairy  50     100      150     100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110     160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60     150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60     170
# 721              Volcanion     Fire   Water  80     110      120     130
#
#      Sp_Def  Speed  Generation  Legendary
# #
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 1 to 721
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type_1      800 non-null    object
#  2   Type_2      414 non-null    object
#  3   HP          800 non-null    int64
#  4   Attack      800 non-null    int64
#  5   Defense     800 non-null    int64
#  6   Sp_Atk      800 non-null    int64
#  7   Sp_Def      800 non-null    int64
#  8   Speed       800 non-null    int64
#  9   Generation  800 non-null    int64
#  10  Legendary   800 non-null    bool
# dtypes: bool(1), int64(7), object(3)
# memory usage: 69.5+ KB

# %%
# I noticed that the column 'Type_2' has a lot of 'Nan', so i had to check

for i in df['Type_2']:
    print(i, end=',')
# Out:
# Poison,Poison,Poison,Poison,nan,nan,Flying,Dragon,Flying,nan,nan,nan,nan,nan,nan,Flying,Poison,Poison,Poison,Poison,Flying,Flying,Flying,Flying,nan,nan,Flying,Flying,nan,nan,nan,nan,nan,nan,nan,nan,Ground,nan,nan,Ground,nan,nan,nan,nan,Fairy,Fairy,Flying,Flying,Poison,Poison,Poison,Grass,Grass,Poison,Poison,nan,nan,nan,nan,nan,nan,nan,nan,nan,nan,nan,nan,Fighting,nan,nan,nan,nan,nan,nan,nan,Poison,Poison,Poison,Poison,Poison,Ground,Ground,Ground,nan,nan,Psychic,Psychic,Psychic,Steel,Steel,Flying,Flying,Flying,nan,Ice,nan,nan,nan,Ice,Poison,Poison,Poison,Poison,Ground,nan,nan,nan,nan,nan,nan,Psychic,Psychic,nan,nan,nan,nan,nan,nan,nan,Rock,Rock,nan,nan,nan,nan,nan,nan,nan,nan,nan,Psychic,Fairy,Flying,Psychic,nan,nan,nan,Flying,nan,nan,Flying,Dark,Ice,nan,nan,nan,nan,nan,nan,Water,Water,Water,Water,Flying,Flying,nan,Flying,Flying,Flying,nan,nan,Flying,nan,Fighting,nan,nan,nan,nan,nan,nan,nan,nan,nan,nan,nan,nan,nan,Flying,Flying,Flying,Flying,Poison,Poison,Flying,Electric,Electric,nan,
# ...

# %%
# I summed all of it up....

df.Type_2.isnull().sum()
# Out:
# 386

# %%
df
# Out:
#                       Name   Type_1  Type_2  HP  Attack  Defense  Sp_Atk  \
# #
# 1                Bulbasaur    Grass  Poison  45      49       49      65
# 2                  Ivysaur    Grass  Poison  60      62       63      80
# 3                 Venusaur    Grass  Poison  80      82       83     100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123     122
# 4               Charmander     Fire     NaN  39      52       43      60
# ..                     ...      ...     ...  ..     ...      ...     ...
# 719                Diancie     Rock   Fairy  50     100      150     100
# 719    DiancieMega Diancie     Rock   Fairy  50     160      110     160
# 720    HoopaHoopa Confined  Psychic   Ghost  80     110       60     150
# 720     HoopaHoopa Unbound  Psychic    Dark  80     160       60     170
# 721              Volcanion     Fire   Water  80     110      120     130
#
#      Sp_Def  Speed  Generation  Legendary
# #
# ...

# %%
# Finding the name and type of pokemon that has speed attack less than 50. Slow pokemon. The average speed of a pokemon is 66

filt = df['Sp_Atk'] < 60

df.loc[filt, ['Name', 'Type_1', 'Type_2']]
# Out:
#                     Name  Type_1  Type_2
# #
# 7               Squirtle   Water     NaN
# 10              Caterpie     Bug     NaN
# 11               Metapod     Bug     NaN
# 13                Weedle     Bug  Poison
# 14                Kakuna     Bug  Poison
# ..                   ...     ...     ...
# 711  GourgeistLarge Size   Ghost   Grass
# 711  GourgeistSuper Size   Ghost   Grass
# 712             Bergmite     Ice     NaN
# 713              Avalugg     Ice     NaN
# 714               Noibat  Flying  Dragon
#
# [299 rows x 3 columns]

# %%
df.loc[filt, ['Name', 'Type_1', 'Type_2']].count()
# Out:
# Name      299
# Type_1    299
# Type_2    143
# dtype: int64

# %%
# Finding the pokemon name and type with the highest sp_atk 

highest_speed = 0
for spd in df.Sp_Atk:
    if spd > highest_speed:
        highest_speed = spd
        
print(highest_speed)


#def speed():
 #   highest_speed = 0
  #  for spd in df.Sp_Atk:
   #     if highest_speed < spd:
    #        highest_speed = spd
    #return highest_speed
    
#speed()
# Out:
# 194

# %%
# I searched the Name using the variable i created, i couldn't get the correct information

df.loc[highest_speed, ['Name', 'Type_1', 'Sp_Atk']]
# Out:
# Name      Wooper
# Type_1     Water
# Sp_Atk        25
# Name: 194, dtype: object

# %%
# I had to improvise and hard-code the number to find the correct information

filt = df['Sp_Atk'] == 194

df.loc[filt, ['Name', 'Type_1', 'Sp_Atk', 'Sp_Def']]
# Out:
#                     Name   Type_1  Sp_Atk  Sp_Def
# #
# 150  MewtwoMega Mewtwo Y  Psychic     194     120

# %%
# Finding the pokemon with the lowest Sp_Atk

lowest_speed = 194

for spd in df.Sp_Atk:
    if spd < lowest_speed:
        lowest_speed = spd
        
print(lowest_speed)
# Out:
# 10

# %%
# 3 dataframe result of pokemon with low Sp_Atk

filt = df['Sp_Atk'] == 10

df.loc[filt, ['Name', 'Type_1', 'Sp_Atk', 'Generation', 'Attack']]
# Out:
#         Name Type_1  Sp_Atk  Generation  Attack
# #
# 213  Shuckle    Bug      10           2      10
# 349   Feebas  Water      10           3      15
# 438   Bonsly   Rock      10           4      80

# %%
filt = df['Name'] == 'MewtwoMega Mewtwo Y'

# %%
df[filt]
# Out:
#                     Name   Type_1 Type_2   HP  Attack  Defense  Sp_Atk  \
# #
# 150  MewtwoMega Mewtwo Y  Psychic    NaN  106     150       70     194
#
#      Sp_Def  Speed  Generation  Legendary
# #
# 150     120    140           1       True

# %%
# Sorted through the 'Grass types' & 'Poison types' to bring out their names, speed and generation

filt = (df['Type_1'] == 'Grass') & (df['Type_2'] == 'Poison') 


df.loc[filt, ['Name', 'Sp_Atk', 'Generation']].head(10)
# Out:
#                      Name  Sp_Atk  Generation
# #
# 1               Bulbasaur      65           1
# 2                 Ivysaur      80           1
# 3                Venusaur     100           1
# 3   VenusaurMega Venusaur     122           1
# 43                 Oddish      75           1
# 44                  Gloom      85           1
# 45              Vileplume     110           1
# 69             Bellsprout      70           1
# 70             Weepinbell      85           1
# 71             Victreebel     100           1

# %%
# Sorted out 10 pokemons with the strongest 10 sp_atk

df.nlargest(10, 'Sp_Atk')
# Out:
#                         Name    Type_1  Type_2   HP  Attack  Defense  Sp_Atk  \
# #
# 150      MewtwoMega Mewtwo Y   Psychic     NaN  106     150       70     194
# 382      KyogrePrimal Kyogre     Water     NaN  100     150       90     180
# 384    RayquazaMega Rayquaza    Dragon  Flying  105     180      100     180
# 386       DeoxysAttack Forme   Psychic     NaN   50     180       20     180
# 65     AlakazamMega Alakazam   Psychic     NaN   55      50       65     175
# 94         GengarMega Gengar     Ghost  Poison   60      65       80     170
# 646       KyuremWhite Kyurem    Dragon     Ice  125     120       90     170
# 720       HoopaHoopa Unbound   Psychic    Dark   80     160       60     170
# 181    AmpharosMega Ampharos  Electric  Dragon   90      95      105     165
# 282  GardevoirMega Gardevoir   Psychic   Fairy   68      85       65     165
#
#      Sp_Def  Speed  Generation  Legendary
# #
# 150     120    140           1       True
# ...

# %%
# Sorting out 10 pokemons with the weakest 10 sp_atk

df.nsmallest(10, 'Sp_Atk')
# Out:
#                       Name  Type_1  Type_2   HP  Attack  Defense  Sp_Atk  \
# #
# 213                Shuckle     Bug    Rock   20      10      230      10
# 349                 Feebas   Water     NaN   20      15       20      10
# 438                 Bonsly    Rock     NaN   50      80       95      10
# 15   BeedrillMega Beedrill     Bug  Poison   65     150       40      15
# 129               Magikarp   Water     NaN   20      10       55      15
# 440                Happiny  Normal     NaN  100       5        5      15
# 554               Darumaka    Fire     NaN   70      90       45      15
# 10                Caterpie     Bug     NaN   45      30       35      20
# 13                  Weedle     Bug  Poison   40      35       30      20
# 27               Sandshrew  Ground     NaN   50      75       85      20
#
#      Sp_Def  Speed  Generation  Legendary
# #
# 213     230      5           2      False
# 349      55     80           3      False
# ...

# %%
df[['Sp_Atk', 'Sp_Def', 'Attack', 'Defense', 'HP', 'Speed']].sum()
# Out:
# Sp_Atk     58256
# Sp_Def     57522
# Attack     63201
# Defense    59074
# HP         55407
# Speed      54622
# dtype: int64

# %%
df[['Sp_Atk', 'Sp_Def', 'Attack', 'Defense', 'HP', 'Speed']].median()
# Out:
# Sp_Atk     65.0
# Sp_Def     70.0
# Attack     75.0
# Defense    70.0
# HP         65.0
# Speed      65.0
# dtype: float64

# %%
# Names, Type_1 and Generations of Pokemons with Type_2 column null values

filt = df.Type_2.isnull()

df.loc[filt, ['Name', 'Type_1', 'Generation']].head(20)
# Out:
#                 Name  Type_1  Generation
# #
# 4         Charmander    Fire           1
# 5         Charmeleon    Fire           1
# 7           Squirtle   Water           1
# 8          Wartortle   Water           1
# 9          Blastoise   Water           1
# ..               ...     ...         ...
# 28         Sandslash  Ground           1
# 29  Nidoran (Female)  Poison           1
# 30          Nidorina  Poison           1
# 32    Nidoran (Male)  Poison           1
# 33          Nidorino  Poison           1
#
# [20 rows x 3 columns]

# %%
df.nlargest(10, 'Speed')
# Out:
#                           Name    Type_1  Type_2  HP  Attack  Defense  Sp_Atk  \
# #
# 386          DeoxysSpeed Forme   Psychic     NaN  50      95       90      95
# 291                    Ninjask       Bug  Flying  61      90       45      50
# 65       AlakazamMega Alakazam   Psychic     NaN  55      50       65     175
# 142  AerodactylMega Aerodactyl      Rock  Flying  80     135       85      70
# 386         DeoxysNormal Forme   Psychic     NaN  50     150       50     150
# 386         DeoxysAttack Forme   Psychic     NaN  50     180       20     180
# 15       BeedrillMega Beedrill       Bug  Poison  65     150       40      15
# 254      SceptileMega Sceptile     Grass  Dragon  70     110       75     145
# 617                   Accelgor       Bug     NaN  80      70       40     100
# 101                  Electrode  Electric     NaN  60      50       70      80
#
#      Sp_Def  Speed  Generation  Legendary
# #
# 386      90    180           3       True
# ...

# %%
lists = []

for p in df['Type_1']:
    if p not in lists:
        lists.append(p)

# %%
lists
# Out:
# ['Grass',
#  'Fire',
#  'Water',
#  'Bug',
#  'Normal',
#  'Poison',
#  'Electric',
#  'Ground',
#  'Fairy',
#  'Fighting',
#  'Psychic',
#  'Rock',
#  'Ghost',
#  'Ice',
#  'Dragon',
#  'Dark',
#  'Steel',
#  'Flying']

# %%
len(lists)
# Out:
# 18
